# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Analysis and Visualization

# %%
# load the data
#data = pd.read_excel("DAILY_LOGS_YEAR_2015.xlsx",  sep = ',', header= None )
data1 = pd.read_excel("../data/DAILY LOGS YEAR 2014.xlsx" )
data2 = pd.read_excel("../data/DAILY LOGS YEAR 2015.xlsx" )
data2.columns=data1.columns
data3 = pd.read_excel("../data/DAILY LOGS YEAR 2016.xlsx" )
data3.columns=data1.columns
data4 = pd.read_excel("../data/DAILY LOGS YEAR 2017.xlsx" )
data4.columns=data1.columns
data5 = pd.read_excel("../data/DAILY LOGS YEAR 2018.xlsx" )
data5.columns=data1.columns
data6 = pd.read_excel("../data/DAILY LOGS YEAR 2019.xlsx" )
data6.columns=data1.columns
data7 = pd.read_excel("../data/DAILY LOGS YEAR 2020.xlsx" )
data7.columns=data1.columns
data8 = pd.read_excel("../data/DAILY LOGS YEAR 2021.xlsx" )
data8.columns=data1.columns

# %%
#Merging data of years (2014-2021)
df_main = pd.concat((data1,data2,data3,data4,data5,data6,data7,data8), ignore_index=True)

# %%
#displaying the first five rows DataFrame
df_main.head()
# Out:
#         DATE      AREA  VOLUME  CONDITION LEVEL WIND DIRECTION MOON PHASE  \
# 0 2014-01-01   CACATAN   100.0              3.0             NE        NaN
# 1 2014-01-01   CACATAN   242.0              3.0             NE        NaN
# 2 2014-01-01     LUGUS   156.0              3.0             NE        NaN
# 3 2014-01-01     LUGUS    97.0              3.0             NE        NaN
# 4 2014-01-01  BAMBANAN   119.0              3.0             NE        NaN
#
#   CURRENT TEMPERATURE
# 0       S         NaN
# 1       S         NaN
# 2       S         NaN
# 3       S         NaN
# 4      SW         NaN

# %%
#displaying the last five rows DataFrame
df_main.tail()
# Out:
#             DATE              AREA  VOLUME  CONDITION LEVEL WIND DIRECTION  \
# 36866 2021-12-30   DRILLINGS SOUTH     0.0              3.0             NE
# 36867 2021-12-30  MANG LUBOT LUBOT   115.0              3.0             NE
# 36868 2021-12-30        WEST GALOK   146.0              3.0             NE
# 36869 2021-12-30        WEST GALOK    29.0              3.0             NE
# 36870 2021-12-30       WEST NALAOT    62.0              3.0             NE
#
#       MOON PHASE CURRENT TEMPERATURE
# 36866        NaN     SWW      28.9°C
# 36867        NaN     NWW      28.1°C
# 36868        NaN      SE      29.3°C
# 36869        NaN      SE      29.3°C
# 36870        NaN     SSE      29.2°C

# %%
#Delete empty columns
emp_col=['TEMPERATURE','MOON PHASE']
df_main =df_main.drop(emp_col, axis = 1)
df_main.head()
# Out:
#         DATE      AREA  VOLUME  CONDITION LEVEL WIND DIRECTION CURRENT
# 0 2014-01-01   CACATAN   100.0              3.0             NE       S
# 1 2014-01-01   CACATAN   242.0              3.0             NE       S
# 2 2014-01-01     LUGUS   156.0              3.0             NE       S
# 3 2014-01-01     LUGUS    97.0              3.0             NE       S
# 4 2014-01-01  BAMBANAN   119.0              3.0             NE      SW

# %%
#Display the shape of DataFrame
df_main.shape
# Out:
# (36871, 6)

# %%
# check missing values in the dataset 
df_main.isnull().sum()
df_main.reset_index(drop=True, inplace=True)

# %%
# Delete rows containing missing values using dropna() function  
df_main=df_main.dropna()

# %%
# check to make sure missing values are removed
df_main.isnull().sum()
# Out:
# DATE               0
# AREA               0
# VOLUME             0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# dtype: int64

# %%
#Display summary statistics of numerical data
df_main['VOLUME'].describe()
# Out:
# count    35262.000000
# mean       280.924366
# std        383.645678
# min          0.000000
# 25%         40.000000
# 50%        150.000000
# 75%        368.000000
# max      11122.000000
# Name: VOLUME, dtype: float64

# %%
#Bar chart to visualize the frequency of any categorical feature e.g CONDITION LEVEL.
#value_counts method is used to calculate the frequency of each category in  condition level feature
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data_1 = df_main['CONDITION LEVEL'].value_counts() 
# get x and y data 
points = data_1.index 
frequency = data_1.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('Condition Level Scores') 
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(df_main['CONDITION LEVEL'])
plt.show()
# Out:
# /home/sajid/anaconda3/envs/project/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Pie-plot of CONDITION LEVEL feature
df_main['CONDITION LEVEL'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
#Histogram of VOLUME feature
#A histogram is a value distribution plot of numerical columns. It basically creates bins in various ranges in values 
#and plots it where we can visualize how values are distributed
plt.hist(df_main['VOLUME'], bins=50)
plt.show()

# %%
sns.distplot(df_main['VOLUME']) 
plt.show()
# Out:
# /home/sajid/anaconda3/envs/project/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Feature Engineering

# %%
#To extract date and time features from DATE column
#The data type of DATE column must be datetime object 
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35262 entries, 0 to 36870
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             35262 non-null  datetime64[ns]
#  1   AREA             35262 non-null  object
#  2   VOLUME           35262 non-null  float64
#  3   CONDITION LEVEL  35262 non-null  float64
#  4   WIND DIRECTION   35262 non-null  object
#  5   CURRENT          35262 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 1.9+ MB

# %%
import datetime

# %%
df_main['month'] = df_main['DATE'].dt.month
df_main['day'] = df_main['DATE'].dt.day
df_main['year'] = df_main['DATE'].dt.year
df_main['dayofweek'] = df_main['DATE'].dt.dayofweek

# %%
df_main.head()
# Out:
#         DATE      AREA  VOLUME  CONDITION LEVEL WIND DIRECTION CURRENT  month  \
# 0 2014-01-01   CACATAN   100.0              3.0             NE       S      1
# 1 2014-01-01   CACATAN   242.0              3.0             NE       S      1
# 2 2014-01-01     LUGUS   156.0              3.0             NE       S      1
# 3 2014-01-01     LUGUS    97.0              3.0             NE       S      1
# 4 2014-01-01  BAMBANAN   119.0              3.0             NE      SW      1
#
#    day  year  dayofweek
# 0    1  2014          2
# 1    1  2014          2
# 2    1  2014          2
# 3    1  2014          2
# 4    1  2014          2

# %%
# check missing values in the dataset 
df_main.isnull().sum()
# Out:
# DATE               0
# AREA               0
# VOLUME             0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# month              0
# day                0
# year               0
# dayofweek          0
# dtype: int64

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35262 entries, 0 to 36870
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             35262 non-null  datetime64[ns]
#  1   AREA             35262 non-null  object
#  2   VOLUME           35262 non-null  float64
#  3   CONDITION LEVEL  35262 non-null  float64
#  4   WIND DIRECTION   35262 non-null  object
#  5   CURRENT          35262 non-null  object
#  6   month            35262 non-null  int64
#  7   day              35262 non-null  int64
#  8   year             35262 non-null  int64
#  9   dayofweek        35262 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.0+ MB

# %%
col_int=["day","month","dayofweek","CONDITION LEVEL"]

# %%
for i in col_int:
    df_main[i] = df_main[i].apply(str)
    print(i)
# Out:
# day
# month
# dayofweek
# CONDITION LEVEL

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35262 entries, 0 to 36870
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             35262 non-null  datetime64[ns]
#  1   AREA             35262 non-null  object
#  2   VOLUME           35262 non-null  float64
#  3   CONDITION LEVEL  35262 non-null  object
#  4   WIND DIRECTION   35262 non-null  object
#  5   CURRENT          35262 non-null  object
#  6   month            35262 non-null  object
#  7   day              35262 non-null  object
#  8   year             35262 non-null  int64
#  9   dayofweek        35262 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 3.0+ MB

# %% [markdown]
# # Visualize the highest volume of product with respect to other features

# %%
#Line plot tovisualize the highest volume of product on yearly basis
g = sns.relplot(x=df_main['year'], y=df_main["VOLUME"], kind="line", data=df_main)
g.figure.autofmt_xdate()

# %%
#Line plot between volume and condition level(subset of data for visualisation purpose)
g = sns.relplot(x=df_main['CONDITION LEVEL'], y=df_main["VOLUME"], kind="line", data=df_main)
g.figure.autofmt_xdate()

# %%
#Line plot between volume and current(subset of data for visualisation purpose)
g = sns.relplot(x=df_main.iloc[0:50, 5], y=df_main["VOLUME"], kind="line", data=df_main)
g.figure.autofmt_xdate()

# %%
#Line plot between volume and area(subset of data for visualisation purpose)
g = sns.relplot(x=df_main.iloc[0:50, 1], y=df_main["VOLUME"], kind="line", data=df_main)
g.figure.autofmt_xdate()

# %%
#Creating the bar plot to compare the values in certain groups and sub-groups
index_no = df_main.columns.get_loc('CURRENT')#extracting index no of feature, we want to plot on x-axis
#hue is the class 
sns.barplot(y = 'VOLUME',x=df_main.iloc[0:50,index_no],hue = 'CONDITION LEVEL',data = df_main, palette = "Oranges")
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('CONDITION LEVEL')
plt.ylabel('VOLUME') 
# Show the plot
plt.show()

# %%
#Creating the bar plot to compare the values in certain groups and sub-groups e.g specific area with multiple condition levels
#hue is the class 
x_df=df_main.loc[df_main['AREA']== 'CACATAN']
sns.barplot(y = 'VOLUME',x='AREA',hue = 'CONDITION LEVEL',data = x_df, palette = "Oranges")
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('CONDITION LEVEL')
plt.ylabel('VOLUME') 
# Show the plot
plt.show()

# %%
df=df_main.copy()

# %%
#LABEL ENCODER
#Import label encoder
from sklearn import preprocessing
def labelenc(df,col_enc):
# #     print(df)
    print(col_enc)
    label_encoder = preprocessing.LabelEncoder()
#reshape the 1-D country array to 2-D as fit_transform expects 2-D and finally fit the object 
    df[col_enc]= label_encoder.fit_transform(df[col_enc])
    return df
 
# df['AREA'].unique()

# %%
lst_categ=["AREA","WIND DIRECTION","CURRENT","year"]

# %%
for i in lst_categ:
    df_main_1=labelenc(df,i)
# Out:
# AREA
# WIND DIRECTION
# CURRENT
# year

# %%
df_main_1.isnull().sum()
# Out:
# DATE               0
# AREA               0
# VOLUME             0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# month              0
# day                0
# year               0
# dayofweek          0
# dtype: int64

# %%
df_main_1.head()
# Out:
#         DATE  AREA  VOLUME CONDITION LEVEL  WIND DIRECTION  CURRENT month day  \
# 0 2014-01-01    78   100.0             3.0               5       29     1   1
# 1 2014-01-01    78   242.0             3.0               5       29     1   1
# 2 2014-01-01   229   156.0             3.0               5       29     1   1
# 3 2014-01-01   229    97.0             3.0               5       29     1   1
# 4 2014-01-01    26   119.0             3.0               5       42     1   1
#
#    year dayofweek
# 0     0         2
# 1     0         2
# 2     0         2
# 3     0         2
# 4     0         2

# %%
df_main_1 =df_main_1.drop("DATE", axis = 1)
df_main_1.reset_index(drop=True, inplace=True)

# %%
df_main_1.head()
# Out:
#    AREA  VOLUME CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year  \
# 0    78   100.0             3.0               5       29     1   1     0
# 1    78   242.0             3.0               5       29     1   1     0
# 2   229   156.0             3.0               5       29     1   1     0
# 3   229    97.0             3.0               5       29     1   1     0
# 4    26   119.0             3.0               5       42     1   1     0
#
#   dayofweek
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2

# %%
df_main_1.isnull().sum()
# Out:
# AREA               0
# VOLUME             0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# month              0
# day                0
# year               0
# dayofweek          0
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
#prepare data for feature selection
x=df_main_1.loc[:, df_main_1.columns!='VOLUME']
y=df_main_1.loc[:,df_main_1.columns=='VOLUME']
x.head()
# Out:
#    AREA CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year dayofweek
# 0    78             3.0               5       29     1   1     0         2
# 1    78             3.0               5       29     1   1     0         2
# 2   229             3.0               5       29     1   1     0         2
# 3   229             3.0               5       29     1   1     0         2
# 4    26             3.0               5       42     1   1     0         2

# %%
y.head()
# Out:
#    VOLUME
# 0   100.0
# 1   242.0
# 2   156.0
# 3    97.0
# 4   119.0

# %%
y.isnull().sum()
# Out:
# VOLUME    0
# dtype: int64

# %%
#importing the necessary libraries
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
# Sequential Forward Selection(sfs)
sfs = SFS(LinearRegression(),
          k_features=8,
          forward=True,
          floating=False,
          scoring = 'r2',
          cv = 0)

# %%
sfs.fit(x, y)
sfs.k_feature_names_
# Out:
# ('AREA',
#  'CONDITION LEVEL',
#  'WIND DIRECTION',
#  'CURRENT',
#  'month',
#  'day',
#  'year',
#  'dayofweek')

# %%
#to find out the optimal number of significant features we can use the hit and trial method for different values 
#of k_features and make the final decision by plotting it against the model performance.
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt
fig1 = plot_sfs(sfs.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/sajid/anaconda3/envs/project/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sajid/anaconda3/envs/project/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Outlier Detection

# %%
from numpy.random import randn
from numpy import mean
from numpy import std
...
# calculate summary statistics
data_mean, data_std = mean(df_main_1['VOLUME']), std(df_main_1['VOLUME'])
# identify outliers
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off

# %%
# outliers = [x for x in df_main_1['VOLUME'] if x < lower or x > upper]

# %%
for i,x in enumerate (df_main_1['VOLUME']):
#     x=df_2.iloc[i][2]
    if x < lower or x > upper:
        df_main_1.loc[i,'outlier']='outlier'
        print("value of volume",x)
        print("lower",lower)
        print("upper",upper)
        print("//////////////////////////////////////")
        print('value is outlier')
        print("/////////////////////////////////////")
    else:
        df_main_1.loc[i,'outlier']='non-outlier'
#         print(i)
# Out:
# value of volume 1700.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2313.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1573.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2619.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2363.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2354.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1850.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1496.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1664.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1535.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1555.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2064.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1946.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1593.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2076.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1534.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1521.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1735.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2376.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2246.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1749.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1594.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2462.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1919.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2388.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2230.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1436.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1499.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2195.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1556.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2602.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2087.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1435.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2265.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1610.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1761.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2158.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1501.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1906.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1501.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3447.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1722.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3604.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2001.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1782.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3011.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2210.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1530.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1637.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1725.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2107.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2267.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1688.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2901.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1498.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2675.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1568.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2045.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1600.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1537.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1811.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2654.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1735.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1985.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2141.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1923.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2444.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3143.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1686.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2570.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1910.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1571.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1678.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1893.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1647.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1789.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1512.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1712.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1991.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1574.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2135.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1669.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2416.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2648.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1629.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1725.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2122.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1585.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1910.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2070.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1942.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1525.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2897.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2062.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2203.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1599.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2115.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1735.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1477.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1984.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2660.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1435.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1560.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1622.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1555.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2104.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1758.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1543.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1458.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1908.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1582.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3048.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1515.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2610.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2078.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1468.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1606.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1981.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2770.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2775.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1473.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1569.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1441.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2552.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1583.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1493.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2280.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1787.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2284.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2261.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1629.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1737.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1753.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1665.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1518.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1550.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1612.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3149.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2968.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1761.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2649.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1543.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2194.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2200.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1770.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1782.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1532.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1571.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2075.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2085.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1980.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1778.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2025.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1556.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1887.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1515.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1555.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1480.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1690.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1561.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1614.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1569.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1670.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1804.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1519.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1480.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1523.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1479.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1546.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1586.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2741.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2191.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2017.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1542.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2345.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1469.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2138.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2404.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1685.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2891.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2660.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1664.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1604.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2180.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2798.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1583.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2529.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1616.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2485.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1957.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1625.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1696.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1500.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1853.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1500.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1773.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1825.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3167.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1545.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1628.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2317.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1775.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1639.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2514.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1819.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1800.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2098.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 9369.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1682.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1774.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1824.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1722.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2427.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1861.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2478.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2112.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1678.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1484.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1750.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1730.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2734.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2226.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1581.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1465.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1433.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1692.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1717.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1642.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1647.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2279.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2149.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2770.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2875.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1710.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1750.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1994.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1631.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2635.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1611.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1486.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1775.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1535.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3330.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2230.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1730.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2526.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1842.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1578.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1462.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2005.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1474.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1964.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2050.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1702.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1562.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1524.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1774.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2303.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1978.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2149.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2035.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2476.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1499.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1782.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1481.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1837.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1457.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1818.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1565.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1833.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1690.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1660.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1462.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1491.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2446.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1828.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2815.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1913.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1979.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1594.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1512.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2132.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1598.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2062.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1470.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1928.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1816.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2139.0
# lower -869.9963489134811
# ...
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1460.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2049.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1727.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1660.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3463.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1983.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2151.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2724.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3774.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2080.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1460.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1767.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2890.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1883.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1630.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1697.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1978.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2264.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1434.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3132.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1588.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1445.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2062.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1536.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1993.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2310.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1992.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2220.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2312.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1460.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2651.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1612.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1438.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1854.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3451.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2960.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2083.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1743.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1756.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2001.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1770.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1733.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1618.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2139.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1519.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2888.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2522.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2070.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2342.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1700.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1549.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2432.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1798.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1976.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1479.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2473.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1816.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1449.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1535.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1743.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1944.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1473.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 11122.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1583.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2019.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1892.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1479.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1509.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1865.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1439.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2120.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3024.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2886.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1963.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1586.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1783.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1453.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1703.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1473.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1665.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2884.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1595.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 3036.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1921.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2531.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1648.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1971.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1451.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1656.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 4391.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1905.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1450.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1734.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 2525.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////
# value of volume 1465.0
# lower -869.9963489134811
# upper 1431.8450812599162
# //////////////////////////////////////
# value is outlier
# /////////////////////////////////////

# %%
df_main_1.head()
# Out:
#    AREA  VOLUME CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year  \
# 0    78   100.0             3.0               5       29     1   1     0
# 1    78   242.0             3.0               5       29     1   1     0
# 2   229   156.0             3.0               5       29     1   1     0
# 3   229    97.0             3.0               5       29     1   1     0
# 4    26   119.0             3.0               5       42     1   1     0
#
#   dayofweek      outlier
# 0         2  non-outlier
# 1         2  non-outlier
# 2         2  non-outlier
# 3         2  non-outlier
# 4         2  non-outlier

# %%
df_main_1.isnull().sum()
# Out:
# AREA               0
# VOLUME             0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# month              0
# day                0
# year               0
# dayofweek          0
# outlier            0
# dtype: int64

# %%
item_counts = df_main_1["outlier"].value_counts()
print(item_counts)
# Out:
# non-outlier    34534
# outlier          728
# Name: outlier, dtype: int64

# %% [markdown]
# # Log Transformation to remove skewness in data

# %%
for i,x in enumerate (df_main_1['VOLUME']):
    if (x!=0):
        df_main_1.loc[i,'VOLUME_log']=np.log(x)
    else:
        df_main_1.loc[i,'VOLUME_log']=0
#     print(i)

# %%
#Outliers after appying log transformation to numerical feature
for i,x in enumerate (df_main_1['VOLUME_log']):
#     x=df_2.iloc[i][2]
    if x < lower or x > upper:
        df_main_1.loc[i,'outlier_after_log']='outlier'
        print("value of volume",x)
        print("lower",lower)
        print("upper",upper)
        print("//////////////////////////////////////")
        print('value is outlier')
        print("/////////////////////////////////////")
    else:
        df_main_1.loc[i,'outlier_after_log']='non-outlier'

# %%
item_counts = df_main_1["outlier_after_log"].value_counts()
print(item_counts)
# Out:
# non-outlier    35262
# Name: outlier_after_log, dtype: int64

# %%
df_main_1.head()
# Out:
#    AREA  VOLUME CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year  \
# 0    78   100.0             3.0               5       29     1   1     0
# 1    78   242.0             3.0               5       29     1   1     0
# 2   229   156.0             3.0               5       29     1   1     0
# 3   229    97.0             3.0               5       29     1   1     0
# 4    26   119.0             3.0               5       42     1   1     0
#
#   dayofweek      outlier  VOLUME_log outlier_after_log
# 0         2  non-outlier    4.605170       non-outlier
# 1         2  non-outlier    5.488938       non-outlier
# 2         2  non-outlier    5.049856       non-outlier
# 3         2  non-outlier    4.574711       non-outlier
# 4         2  non-outlier    4.779123       non-outlier

# %%
col=["outlier","VOLUME","outlier_after_log"]
df_main_1 =df_main_1.drop(col, axis = 1)

# %%
df_main_1.head()
# Out:
#    AREA CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year dayofweek  \
# 0    78             3.0               5       29     1   1     0         2
# 1    78             3.0               5       29     1   1     0         2
# 2   229             3.0               5       29     1   1     0         2
# 3   229             3.0               5       29     1   1     0         2
# 4    26             3.0               5       42     1   1     0         2
#
#    VOLUME_log
# 0    4.605170
# 1    5.488938
# 2    5.049856
# 3    4.574711
# 4    4.779123

# %%
df_main_1.isnull().sum()
# Out:
# AREA               0
# CONDITION LEVEL    0
# WIND DIRECTION     0
# CURRENT            0
# month              0
# day                0
# year               0
# dayofweek          0
# VOLUME_log         0
# dtype: int64

# %% [markdown]
# # Make Multiple Shifted (Lagged) Columns in Pandas

# %%
# lags = range(1, 3)  # Just two lags for demonstration.
# col_1=["VOLUME_log"]
# df_prac=df_main_1.copy()
# df_main_1.assign(**{
# f'{col} (t-{lag})': df_main_1[col_1].shift(lag)
# for lag in lags
# for col in df_main_1[col_1]

# })

# %%
lags = range(1, 31)  # 5 lags
col_1=["VOLUME_log"]
# df_prac_1=df_main_1.copy()
df_main_1=df_main_1.assign(**{'{} (t-{})'.format(col, t): df_main_1[col].shift(t)
    for t in lags
    for col in df_main_1[col_1]
})

# %%
df_main_1
# Out:
#        AREA CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year  \
# 0        78             3.0               5       29     1   1     0
# 1        78             3.0               5       29     1   1     0
# 2       229             3.0               5       29     1   1     0
# 3       229             3.0               5       29     1   1     0
# 4        26             3.0               5       42     1   1     0
# ...     ...             ...             ...      ...   ...  ..   ...
# 35257   134             3.0               5       47    12  30     7
# 35258   258             3.0               5       28    12  30     7
# 35259   464             3.0               5       30    12  30     7
# 35260   464             3.0               5       30    12  30     7
# 35261   466             3.0               5       38    12  30     7
#
#       dayofweek  VOLUME_log
# 0             2    4.605170
# 1             2    5.488938
# 2             2    5.049856
# 3             2    4.574711
# 4             2    4.779123
# ...         ...         ...
# 35257         3    0.000000
# 35258         3    4.744932
# 35259         3    4.983607
# 35260         3    3.367296
# 35261         3    4.127134
#
# [35262 rows x 9 columns]

# %%
df_main_1.isnull().sum(axis = 0)
# Out:
# AREA                  0
# CONDITION LEVEL       0
# WIND DIRECTION        0
# CURRENT               0
# month                 0
# day                   0
# year                  0
# dayofweek             0
# VOLUME_log            0
# VOLUME_log (t-1)      1
# VOLUME_log (t-2)      2
# VOLUME_log (t-3)      3
# VOLUME_log (t-4)      4
# VOLUME_log (t-5)      5
# VOLUME_log (t-6)      6
# VOLUME_log (t-7)      7
# VOLUME_log (t-8)      8
# VOLUME_log (t-9)      9
# VOLUME_log (t-10)    10
# VOLUME_log (t-11)    11
# VOLUME_log (t-12)    12
# VOLUME_log (t-13)    13
# VOLUME_log (t-14)    14
# VOLUME_log (t-15)    15
# VOLUME_log (t-16)    16
# VOLUME_log (t-17)    17
# VOLUME_log (t-18)    18
# VOLUME_log (t-19)    19
# VOLUME_log (t-20)    20
# VOLUME_log (t-21)    21
# VOLUME_log (t-22)    22
# VOLUME_log (t-23)    23
# VOLUME_log (t-24)    24
# VOLUME_log (t-25)    25
# VOLUME_log (t-26)    26
# VOLUME_log (t-27)    27
# VOLUME_log (t-28)    28
# VOLUME_log (t-29)    29
# VOLUME_log (t-30)    30
# dtype: int64

# %%
df_main_1=df_main_1.dropna()

# %%
df_main_1.isnull().sum(axis = 0)
# Out:
# AREA                 0
# CONDITION LEVEL      0
# WIND DIRECTION       0
# CURRENT              0
# month                0
# day                  0
# year                 0
# dayofweek            0
# VOLUME_log           0
# VOLUME_log (t-1)     0
# VOLUME_log (t-2)     0
# VOLUME_log (t-3)     0
# VOLUME_log (t-4)     0
# VOLUME_log (t-5)     0
# VOLUME_log (t-6)     0
# VOLUME_log (t-7)     0
# VOLUME_log (t-8)     0
# VOLUME_log (t-9)     0
# VOLUME_log (t-10)    0
# VOLUME_log (t-11)    0
# VOLUME_log (t-12)    0
# VOLUME_log (t-13)    0
# VOLUME_log (t-14)    0
# VOLUME_log (t-15)    0
# VOLUME_log (t-16)    0
# VOLUME_log (t-17)    0
# VOLUME_log (t-18)    0
# VOLUME_log (t-19)    0
# VOLUME_log (t-20)    0
# VOLUME_log (t-21)    0
# VOLUME_log (t-22)    0
# VOLUME_log (t-23)    0
# VOLUME_log (t-24)    0
# VOLUME_log (t-25)    0
# VOLUME_log (t-26)    0
# VOLUME_log (t-27)    0
# VOLUME_log (t-28)    0
# VOLUME_log (t-29)    0
# VOLUME_log (t-30)    0
# dtype: int64

# %%
# example of training a final regression model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression

# %%
x=df_main_1.loc[:, df_main_1.columns!='VOLUME_log']
y=df_main_1.loc[:,df_main_1.columns=='VOLUME_log']
x.head()
# Out:
#     AREA CONDITION LEVEL  WIND DIRECTION  CURRENT month day  year dayofweek  \
# 30    78             3.0               5       30     1   3     0         4
# 31    78             3.0               5       30     1   3     0         4
# 32   230             3.0               5       30     1   3     0         4
# 33   230             3.0               5       30     1   3     0         4
# 34   229             3.0               5       38     1   3     0         4
#
#     VOLUME_log (t-1)  VOLUME_log (t-2)  ...  VOLUME_log (t-21)  \
# 30          6.648985          4.691348  ...           4.634729
# 31          4.795791          6.648985  ...           5.398163
# 32          6.224558          4.795791  ...           4.624973
# 33          5.068904          6.224558  ...           4.897840
# 34          5.375278          5.068904  ...           5.327876
#
#     VOLUME_log (t-22)  VOLUME_log (t-23)  VOLUME_log (t-24)  \
# 30           4.927254           4.276666           3.367296
# 31           4.634729           4.927254           4.276666
# 32           5.398163           4.634729           4.927254
# 33           4.624973           5.398163           4.634729
# 34           4.897840           4.624973           5.398163
#
#     VOLUME_log (t-25)  VOLUME_log (t-26)  VOLUME_log (t-27)  \
# 30           0.000000           4.779123           4.574711
# 31           3.367296           0.000000           4.779123
# 32           4.276666           3.367296           0.000000
# 33           4.927254           4.276666           3.367296
# 34           4.634729           4.927254           4.276666
#
#     VOLUME_log (t-28)  VOLUME_log (t-29)  VOLUME_log (t-30)
# 30           5.049856           5.488938           4.605170
# 31           4.574711           5.049856           5.488938
# 32           4.779123           4.574711           5.049856
# 33           0.000000           4.779123           4.574711
# 34           3.367296           0.000000           4.779123
#
# [5 rows x 38 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =  train_test_split(x,y,test_size = 0.2, random_state= 0)

# %%
x_train.isnull().sum()
# Out:
# AREA                 0
# CONDITION LEVEL      0
# WIND DIRECTION       0
# CURRENT              0
# month                0
# day                  0
# year                 0
# dayofweek            0
# VOLUME_log (t-1)     0
# VOLUME_log (t-2)     0
# VOLUME_log (t-3)     0
# VOLUME_log (t-4)     0
# VOLUME_log (t-5)     0
# VOLUME_log (t-6)     0
# VOLUME_log (t-7)     0
# VOLUME_log (t-8)     0
# VOLUME_log (t-9)     0
# VOLUME_log (t-10)    0
# VOLUME_log (t-11)    0
# VOLUME_log (t-12)    0
# VOLUME_log (t-13)    0
# VOLUME_log (t-14)    0
# VOLUME_log (t-15)    0
# VOLUME_log (t-16)    0
# VOLUME_log (t-17)    0
# VOLUME_log (t-18)    0
# VOLUME_log (t-19)    0
# VOLUME_log (t-20)    0
# VOLUME_log (t-21)    0
# VOLUME_log (t-22)    0
# VOLUME_log (t-23)    0
# VOLUME_log (t-24)    0
# VOLUME_log (t-25)    0
# VOLUME_log (t-26)    0
# VOLUME_log (t-27)    0
# VOLUME_log (t-28)    0
# VOLUME_log (t-29)    0
# VOLUME_log (t-30)    0
# dtype: int64

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
r2_score(y_test, ypred), mean_absolute_error(y_test, ypred), np.sqrt(mean_squared_error(y_test, ypred))
# Out:
# (0.2784491564412237, 1.2679819167925757, 1.6713904044251169)

# %% [markdown]
# # Linear Regression_model_1(AREA, DATE)

# %%
df_model_1=df_main_1.copy()


col_mod_1=['CONDITION LEVEL','WIND DIRECTION','CURRENT']
df_model_1 =df_model_1.drop(col_mod_1, axis = 1)
df_model_1.head()
# Out:
#    AREA month day  year dayofweek  VOLUME_log
# 0    78     1   1     0         2    4.605170
# 1    78     1   1     0         2    5.488938
# 2   229     1   1     0         2    5.049856
# 3   229     1   1     0         2    4.574711
# 4    26     1   1     0         2    4.779123

# %%
lags = range(1, 31)  # 5 lags
col_1=["VOLUME_log"]
# df_prac_1=df_main_1.copy()
df_model_1=df_model_1.assign(**{'{} (t-{})'.format(col, t): df_model_1[col].shift(t)
    for t in lags
    for col in df_model_1[col_1]
})

# %%
df_model_1=df_model_1.dropna()

# %%
x_m_1=df_model_1.loc[:, df_model_1.columns!='VOLUME_log']
y_m_1=df_model_1.loc[:,df_model_1.columns=='VOLUME_log']
x_m_1.head()
# Out:
#     AREA month day  year dayofweek  VOLUME_log (t-1)  VOLUME_log (t-2)  \
# 30    78     1   3     0         4          6.648985          4.691348
# 31    78     1   3     0         4          4.795791          6.648985
# 32   230     1   3     0         4          6.224558          4.795791
# 33   230     1   3     0         4          5.068904          6.224558
# 34   229     1   3     0         4          5.375278          5.068904
#
#     VOLUME_log (t-3)  VOLUME_log (t-4)  VOLUME_log (t-5)  ...  \
# 30          0.000000          5.513429          2.708050  ...
# 31          4.691348          0.000000          5.513429  ...
# 32          6.648985          4.691348          0.000000  ...
# 33          4.795791          6.648985          4.691348  ...
# 34          6.224558          4.795791          6.648985  ...
#
#     VOLUME_log (t-21)  VOLUME_log (t-22)  VOLUME_log (t-23)  \
# 30           4.634729           4.927254           4.276666
# 31           5.398163           4.634729           4.927254
# 32           4.624973           5.398163           4.634729
# 33           4.897840           4.624973           5.398163
# 34           5.327876           4.897840           4.624973
#
#     VOLUME_log (t-24)  VOLUME_log (t-25)  VOLUME_log (t-26)  \
# 30           3.367296           0.000000           4.779123
# 31           4.276666           3.367296           0.000000
# 32           4.927254           4.276666           3.367296
# 33           4.634729           4.927254           4.276666
# 34           5.398163           4.634729           4.927254
#
#     VOLUME_log (t-27)  VOLUME_log (t-28)  VOLUME_log (t-29)  VOLUME_log (t-30)
# 30           4.574711           5.049856           5.488938           4.605170
# 31           4.779123           4.574711           5.049856           5.488938
# 32           0.000000           4.779123           4.574711           5.049856
# 33           3.367296           0.000000           4.779123           4.574711
# 34           4.276666           3.367296           0.000000           4.779123
#
# [5 rows x 35 columns]

# %%
y.head()
# Out:
#    VOLUME
# 0   100.0
# 1   242.0
# 2   156.0
# 3    97.0
# 4   119.0

# %%
from sklearn.model_selection import train_test_split
x_train_m_1, x_test_m_1, y_train_m_1, y_test_m_1 =  train_test_split(x_m_1,y_m_1,test_size = 0.2, random_state= 0)

# %%
model_1 = LinearRegression()
model_1.fit(x_train_m_1, y_train_m_1)
# Out:
# LinearRegression()

# %%
ypred_1 = model_1.predict(x_test_m_1)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
r2_score(y_test_m_1, ypred_1)
# Out:
# 0.25226456002774955

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(x_m_1, y_m_1)
regr_2.fit(x_m_1, y_m_1)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_1 = regr_1.predict(x_test_m_1)
y_2 = regr_2.predict(x_test_m_1)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
r2_score(y_test_m_1, y_1)
# Out:
# 0.1735178284196338

# %%
r2_score(y_test_m_1, y_2)
# Out:
# 0.23147148254610983

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(verbose=1)

# %%
rf.fit(x_train_m_1, y_train_m_1.values.ravel())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.3min finished
# RandomForestRegressor(verbose=1)

# %%
pred_test_rf = rf.predict(x_test_m_1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
r2_score(y_test_m_1, pred_test_rf)
# Out:
# 0.24038661644478432

# %% [markdown]
# # XG BOOST

# %%
import xgboost as xgb
# Instantiation
xgb_r = xgb.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 123,enable_categorical=True)

# %%
x_train_m_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28185 entries, 9282 to 2762
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AREA               28185 non-null  int64
#  1   month              28185 non-null  object
#  2   day                28185 non-null  object
#  3   year               28185 non-null  int64
#  4   dayofweek          28185 non-null  object
#  5   VOLUME_log (t-1)   28185 non-null  float64
#  6   VOLUME_log (t-2)   28185 non-null  float64
#  7   VOLUME_log (t-3)   28185 non-null  float64
#  8   VOLUME_log (t-4)   28185 non-null  float64
#  9   VOLUME_log (t-5)   28185 non-null  float64
#  10  VOLUME_log (t-6)   28185 non-null  float64
#  11  VOLUME_log (t-7)   28185 non-null  float64
#  12  VOLUME_log (t-8)   28185 non-null  float64
#  13  VOLUME_log (t-9)   28185 non-null  float64
#  14  VOLUME_log (t-10)  28185 non-null  float64
#  15  VOLUME_log (t-11)  28185 non-null  float64
#  16  VOLUME_log (t-12)  28185 non-null  float64
#  17  VOLUME_log (t-13)  28185 non-null  float64
#  18  VOLUME_log (t-14)  28185 non-null  float64
#  19  VOLUME_log (t-15)  28185 non-null  float64
#  20  VOLUME_log (t-16)  28185 non-null  float64
#  21  VOLUME_log (t-17)  28185 non-null  float64
#  22  VOLUME_log (t-18)  28185 non-null  float64
#  23  VOLUME_log (t-19)  28185 non-null  float64
#  24  VOLUME_log (t-20)  28185 non-null  float64
#  25  VOLUME_log (t-21)  28185 non-null  float64
#  26  VOLUME_log (t-22)  28185 non-null  float64
#  27  VOLUME_log (t-23)  28185 non-null  float64
#  28  VOLUME_log (t-24)  28185 non-null  float64
#  29  VOLUME_log (t-25)  28185 non-null  float64
#  30  VOLUME_log (t-26)  28185 non-null  float64
#  31  VOLUME_log (t-27)  28185 non-null  float64
#  32  VOLUME_log (t-28)  28185 non-null  float64
#  33  VOLUME_log (t-29)  28185 non-null  float64
#  34  VOLUME_log (t-30)  28185 non-null  float64
# dtypes: float64(30), int64(2), object(3)
# memory usage: 7.7+ MB

# %%
# # Train and test set are converted to DMatrix objects,
# # as it is required by learning API.
# # convert to DMatrix
# d_train = xgb.DMatrix(x_train_m_1, y_train_m_1)
# d_test = xgb.DMatrix(x_test_m_1, y_test_m_1)

# %%
# # Fitting the model
# xgb_r.fit(x_train_m_1, y_train_m_1)

# %% [markdown]
# # Linear Regression_model_1(AREA, DATE, CURRENT, WIND)

# %%
df_model_2=df_main_1.copy()


col_mod_2=['CONDITION LEVEL']
df_model_2 =df_model_2.drop(col_mod_2, axis = 1)
df_model_2.head()
# Out:
#    AREA  WIND DIRECTION  CURRENT month day  year dayofweek  VOLUME_log
# 0    78               5       29     1   1     0         2    4.605170
# 1    78               5       29     1   1     0         2    5.488938
# 2   229               5       29     1   1     0         2    5.049856
# 3   229               5       29     1   1     0         2    4.574711
# 4    26               5       42     1   1     0         2    4.779123
